# %% [markdown]
# ADP论文的开源代码,改进特征工程环节

# %% [markdown]
# # Downloading and Reading the CSI Dataset

# %%
# Use the following commands to download parts of the dichasus-cf0x dataset.
# This tutorial uses the "old" dataset version (not "rev2") - do not manually download the dataset from the website.
# If you need to manually download the dataset from your browser, please use this website instead:
# https://darus.uni-stuttgart.de/dataset.xhtml?persistentId=doi:10.18419/DARUS-2854&version=2.0
# !mkdir dichasus
# !wget -nc --content-disposition https://darus.uni-stuttgart.de/api/access/datafile/:persistentId?persistentId=doi:10.18419/darus-2854/8 -P dichasus # dichasus-cf02
# !wget -nc --content-disposition https://darus.uni-stuttgart.de/api/access/datafile/:persistentId?persistentId=doi:10.18419/darus-2854/9 -P dichasus # dichasus-cf03
# !wget -nc --content-disposition https://darus.uni-stuttgart.de/api/access/datafile/:persistentId?persistentId=doi:10.18419/darus-2854/10 -P dichasus # dichasus-cf04
# !wget -nc https://dichasus.inue.uni-stuttgart.de/datasets/data/dichasus-cf0x/reftx-offsets-dichasus-cf02.json -P dichasus
# !wget -nc https://dichasus.inue.uni-stuttgart.de/datasets/data/dichasus-cf0x/reftx-offsets-dichasus-cf03.json -P dichasus
# !wget -nc https://dichasus.inue.uni-stuttgart.de/datasets/data/dichasus-cf0x/reftx-offsets-dichasus-cf04.json -P dichasus

# %%
from sklearn.neighbors import NearestNeighbors, kneighbors_graph
from sklearn.manifold import trustworthiness
from scipy.sparse.csgraph import dijkstra
from scipy.spatial import distance_matrix
from sklearn.manifold import MDS
import matplotlib.pyplot as plt
import multiprocessing as mp
from tqdm.auto import tqdm
import tensorflow as tf
import numpy as np
import random
import queue
import json
        

# Antenna definitions
ASSIGNMENTS = [
    [0, 13, 31, 29, 3, 7, 1, 12 ],
    [30, 26, 21, 25, 24, 8, 22, 15],
    [28, 5, 10, 14, 6, 2, 16, 18],
    [19, 4, 23, 17, 20, 11, 9, 27]
]

ANTENNACOUNT = np.sum([len(antennaArray) for antennaArray in ASSIGNMENTS])

def load_calibrate_timedomain(path, offset_path):
    offsets = None
    with open(offset_path, "r") as offsetfile:
        offsets = json.load(offsetfile)
    
    def record_parse_function(proto):
        record = tf.io.parse_single_example(
            proto,
            {
                "csi": tf.io.FixedLenFeature([], tf.string, default_value=""),
                "pos-tachy": tf.io.FixedLenFeature([], tf.string, default_value=""),
                "time": tf.io.FixedLenFeature([], tf.float32, default_value=0),
            },
        )

        csi = tf.ensure_shape(tf.io.parse_tensor(record["csi"], out_type=tf.float32), (ANTENNACOUNT, 1024, 2))   #CSI向量（32，1024，2）
        csi = tf.complex(csi[:, :, 0], csi[:, :, 1])   #合并为复数 （32，1024）
        csi = tf.signal.fftshift(csi, axes=1)  #FFT移位，0频率移到中心

        position = tf.ensure_shape(tf.io.parse_tensor(record["pos-tachy"], out_type=tf.float64), (3))
        time = tf.ensure_shape(record["time"], ())

        return csi, position[:2], time

    def apply_calibration(csi, pos, time):
        sto_offset = tf.tensordot(tf.constant(offsets["sto"]), 2 * np.pi * tf.range(tf.shape(csi)[1], dtype = np.float32) / tf.cast(tf.shape(csi)[1], np.float32), axes = 0)
        cpo_offset = tf.tensordot(tf.constant(offsets["cpo"]), tf.ones(tf.shape(csi)[1], dtype = np.float32), axes = 0)
        csi = tf.multiply(csi, tf.exp(tf.complex(0.0, sto_offset + cpo_offset)))

        return csi, pos, time

    def csi_time_domain(csi, pos, time):
        csi = tf.signal.fftshift(tf.signal.ifft(tf.signal.fftshift(csi, axes=1)),axes=1)

        return csi, pos, time

    def cut_out_taps(tap_start, tap_stop):
        def cut_out_taps_func(csi, pos, time):
            return csi[:,tap_start:tap_stop], pos, time

        return cut_out_taps_func

    def order_by_antenna_assignments(csi, pos, time):
        csi = tf.stack([tf.gather(csi, antenna_inidces) for antenna_inidces in ASSIGNMENTS])
        return csi, pos, time
    
    dataset = tf.data.TFRecordDataset(path)
    
    dataset = dataset.map(record_parse_function, num_parallel_calls = tf.data.AUTOTUNE)
    dataset = dataset.map(apply_calibration, num_parallel_calls = tf.data.AUTOTUNE)
    dataset = dataset.map(csi_time_domain, num_parallel_calls = tf.data.AUTOTUNE)
    dataset = dataset.map(cut_out_taps(507, 520), num_parallel_calls = tf.data.AUTOTUNE)
    dataset = dataset.map(order_by_antenna_assignments, num_parallel_calls = tf.data.AUTOTUNE)

    return dataset

inputpaths = [
    {
        "tfrecords" : "dichasus/dichasus-cf02.tfrecords",
        "offsets" : "dichasus/reftx-offsets-dichasus-cf02.json"
    },
    {
        "tfrecords" : "dichasus/dichasus-cf03.tfrecords",
        "offsets" : "dichasus/reftx-offsets-dichasus-cf03.json"
    },
    {
        "tfrecords" : "dichasus/dichasus-cf04.tfrecords",
        "offsets" : "dichasus/reftx-offsets-dichasus-cf04.json"
    }
]

full_dataset = load_calibrate_timedomain(inputpaths[0]["tfrecords"], inputpaths[0]["offsets"])

for path in inputpaths[1:]:
    full_dataset = full_dataset.concatenate(load_calibrate_timedomain(path["tfrecords"], path["offsets"]))

# %%
# Decimate dataset: Use only every 4th datapoint (to reduce number of points)
training_set = full_dataset.shard(4, 0)

# %% [markdown]
# # From TensorFlow to NumPy

# %% [markdown]
# 转换原因：
# 1.传统机器学习库的需要，大多数scikit-learn算法需要numpy数组输入；科学计算生态系统的兼容
# 2.numpy针对CPU操作优化，可以一次性加载到内存，对于小到中等数据集内存缓存可以加速迭代
# 3.tensorflow在调试的时候不方便，需要eval或numpy才能看到值

# %%
groundtruth_positions = []
csi_time_domain = []
timestamps = []

for csi, pos, time in training_set.batch(1000):
    csi_time_domain.append(csi.numpy())
    groundtruth_positions.append(pos.numpy())
    timestamps.append(time.numpy())

csi_time_domain = np.concatenate(csi_time_domain)
groundtruth_positions = np.concatenate(groundtruth_positions)
timestamps = np.concatenate(timestamps)
# Out:
# 2026-01-09 12:36:35.770670: I tensorflow/core/kernels/data/tf_record_dataset_op.cc:390] TFRecordDataset `buffer_size` is unspecified, default to 262144
# 2026-01-09 12:36:51.168700: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# # Visualizing the Dataset

# %%
def plot_colorized(positions, groundtruth_positions, title = None, show = True, alpha = 1.0):
    # Generate RGB colors for datapoints
    center_point = np.zeros(2, dtype = np.float32)
    center_point[0] = 0.5 * (np.min(groundtruth_positions[:, 0], axis = 0) + np.max(groundtruth_positions[:, 0], axis = 0))
    center_point[1] = 0.5 * (np.min(groundtruth_positions[:, 1], axis = 0) + np.max(groundtruth_positions[:, 1], axis = 0))
    NormalizeData = lambda in_data : (in_data - np.min(in_data)) / (np.max(in_data) - np.min(in_data))
    rgb_values = np.zeros((groundtruth_positions.shape[0], 3))
    rgb_values[:, 0] = 1 - 0.9 * NormalizeData(groundtruth_positions[:, 0])
    rgb_values[:, 1] = 0.8 * NormalizeData(np.square(np.linalg.norm(groundtruth_positions - center_point, axis=1)))
    rgb_values[:, 2] = 0.9 * NormalizeData(groundtruth_positions[:, 1])

    # Plot datapoints
    plt.figure(figsize=(6, 6))
    if title is not None:
        plt.title(title, fontsize=16)
    plt.scatter(positions[:, 0], positions[:, 1], c = rgb_values, alpha = alpha, s = 10, linewidths = 0)
    plt.xlabel("x coordinate")
    plt.ylabel("y coordinate")
    if show:
        plt.show()

plot_colorized(groundtruth_positions, groundtruth_positions, title="Ground Truth Positions")

# %% [markdown]
# # Dissimilarity Metrics and Dissimilarity Matrix Computation

# %% [markdown]
# ### Step 1: ADP-based dissimilarity matrix

# %%
adp_dissimilarity_matrix = np.zeros((csi_time_domain.shape[0], csi_time_domain.shape[0]),dtype=np.float32)

def adp_dissimilarities_worker(todo_queue, output_queue):
    def adp_dissimilarities(index):
        # h has shape (arrays, antennas, taps), w has shape (datapoints, arrays, antennas, taps)
        h = csi_time_domain[index,:,:,:]
        w = csi_time_domain[index:,:,:,:]
            
        dotproducts = np.abs(np.einsum("bmt,lbmt->lbt", np.conj(h), w, optimize = "optimal"))**2
        norms = np.real(np.einsum("bmt,bmt->bt", h, np.conj(h), optimize = "optimal") * np.einsum("lbmt,lbmt->lbt", w, np.conj(w), optimize = "optimal"))
        
        return np.sum(1 - dotproducts / norms, axis = (1, 2))

    while True:
        index = todo_queue.get()

        if index == -1:
            output_queue.put((-1, None))
            break
        
        output_queue.put((index, adp_dissimilarities(index)))

with tqdm(total = csi_time_domain.shape[0]**2) as pbar:
    todo_queue = mp.Queue()
    output_queue = mp.Queue()

    for i in range(csi_time_domain.shape[0]):
        todo_queue.put(i)
    
    for i in range(mp.cpu_count()):
        todo_queue.put(-1)
        p = mp.Process(target = adp_dissimilarities_worker, args = (todo_queue, output_queue))
        p.start()

    finished_processes = 0
    while finished_processes != mp.cpu_count():
        i, d = output_queue.get()

        if i == -1:
            finished_processes = finished_processes + 1
        else:
            adp_dissimilarity_matrix[i,i:] = d
            adp_dissimilarity_matrix[i:,i] = d
            pbar.update(2 * len(d) - 1)
# Out:
# 100%|██████████| 1763412049/1763412049 [02:45<00:00, 10626125.06it/s]

# %% [markdown]
# ### Step 2: Timestamp-based dissimilarity matrix

# %%
# Compute timestamp-based dissimilarity matrix
timestamp_dissimilarity_matrix = np.abs(np.subtract.outer(timestamps, timestamps))

# %% [markdown]
# ### Step 3: Fusing $\mathbf D_\mathrm{ADP}$ with $\mathbf D_\mathrm{time}$

# %%
TIME_THRESHOLD = 2
small_time_dissimilarity_indices = np.logical_and(timestamp_dissimilarity_matrix < TIME_THRESHOLD, timestamp_dissimilarity_matrix > 0)
small_time_dissimilarities = timestamp_dissimilarity_matrix[small_time_dissimilarity_indices]
small_adp_dissimilarities = adp_dissimilarity_matrix[small_time_dissimilarity_indices]

n_bins = 1500

fig, ax1 = plt.subplots()
occurences, edges, patches = ax1.hist(small_adp_dissimilarities / small_time_dissimilarities, range = (0, 50), bins = n_bins)
ax1.set_xlabel("$D_\mathrm{APDP} / D_\mathrm{time}$")
ax1.set_ylabel("Number of Occurences")
# Out:
# Text(0, 0.5, 'Number of Occurences')

# %%
bin_centers = edges[:-1] + np.diff(edges) / 2.
max_bin = np.argmax(occurences)
min_threshold = np.quantile(occurences[:max_bin], 0.5)

for threshold_bin in range(max_bin - 1, -1, -1):
    if occurences[threshold_bin] < min_threshold:
        break

scaling_factor = bin_centers[threshold_bin]

plt.bar(bin_centers[:max_bin], occurences[:max_bin], width = edges[1] - edges[0])
plt.axhline(y = min_threshold, color = 'r', linestyle = '-')
plt.text(4, min_threshold + 10, "Mode Separation Threshold", color = 'r',)
plt.axvline(x = scaling_factor, color = 'r', linestyle = '-')
plt.xlabel("$D_\mathrm{APDP} / D_\mathrm{time}$")
plt.ylabel("Number of Occurences")
plt.show()

print("gamma = ", scaling_factor)
# Out:
# gamma =  12.683333396911621

# %%
# Fuse ADP-based and time-based dissimilarity matrices
dissimilarity_matrix_fused = np.minimum(adp_dissimilarity_matrix, timestamp_dissimilarity_matrix * scaling_factor)

# %% [markdown]
# ### Step 4: Geodesic Dissimilarity Matrix

# %%
n_neighbors = 20

nbrs_alg = NearestNeighbors(n_neighbors = n_neighbors, metric="precomputed", n_jobs = -1)
nbrs = nbrs_alg.fit(dissimilarity_matrix_fused)
nbg = kneighbors_graph(nbrs, n_neighbors, metric = "precomputed", mode="distance")

# %%
dissimilarity_matrix_geodesic = np.zeros((nbg.shape[0], nbg.shape[1]), dtype = np.float32)

def shortest_path_worker(todo_queue, output_queue):
    while True:
        index = todo_queue.get()

        if index == -1:
            output_queue.put((-1, None))
            break

        d = dijkstra(nbg, directed=False, indices=index)
        output_queue.put((index, d))

with tqdm(total = nbg.shape[0]**2) as pbar:
    todo_queue = mp.Queue()
    output_queue = mp.Queue()

    for i in range(nbg.shape[0]):
        todo_queue.put(i)
    
    for i in range(mp.cpu_count()):
        todo_queue.put(-1)
        p = mp.Process(target = shortest_path_worker, args = (todo_queue, output_queue))
        p.start()

    finished_processes = 0
    while finished_processes != mp.cpu_count():
        i, d = output_queue.get()

        if i == -1:
            finished_processes = finished_processes + 1
        else:
            dissimilarity_matrix_geodesic[i,:] = d
            pbar.update(len(d))
# Out:
# 100%|██████████| 1763412049/1763412049 [00:56<00:00, 31460134.51it/s]

# %%
# Compute distances between groundtruth positions
groundtruth_distance_matrix = distance_matrix(groundtruth_positions, groundtruth_positions)

# %%
def plot_dissimilarity_over_euclidean_distance(dissimilarity_matrix, distance_matrix, label = None):
    nth_reduction = 10
    dissimilarities_flat = dissimilarity_matrix[::nth_reduction, ::nth_reduction].flatten()
    distances_flat = distance_matrix[::nth_reduction, ::nth_reduction].flatten()
    
    max_distance = np.max(distances_flat)
    bins = np.linspace(0, max_distance, 100)
    bin_indices = np.digitize(distances_flat, bins)
    
    bin_medians = np.zeros(len(bins) - 1)
    bin_25_perc = np.zeros(len(bins) - 1)
    bin_75_perc = np.zeros(len(bins) - 1)
    for i in range(1, len(bins)):
        bin_values = dissimilarities_flat[bin_indices == i]
        bin_25_perc[i - 1], bin_medians[i - 1], bin_75_perc[i - 1] = np.percentile(bin_values, [25, 50, 75])
    
    plt.plot(bins[:-1], bin_medians, label = label)
    plt.fill_between(bins[:-1], bin_25_perc, bin_75_perc, alpha=0.5)
    
plt.figure(figsize=(8,4))

plot_dissimilarity_over_euclidean_distance(dissimilarity_matrix_geodesic, groundtruth_distance_matrix, "G-fuse")
plot_dissimilarity_over_euclidean_distance(scaling_factor * adp_dissimilarity_matrix, groundtruth_distance_matrix, "ADP")

plt.legend()
plt.xlabel("Euclidean Distance [m]")
plt.ylabel("Scaled Dissimilarity")
plt.show()

# %% [markdown]
# 1.降采样与展平，减少计算量，并把二维矩阵拉平为一维数组
# 2.基于物理距离分箱
# 3.计算箱内统计量，提取落在这个距离范围的所有差异度数值，计算中位数和上下四分位数。中位数-代表这个物理距离下的典型差异度；25%和75%代表数据的离散程度。实线绘制中位数曲线，阴影带填充表示该方法的不确定性。
# 评价：
# 理想状态-线性上升，阴影带窄；ADP曲线，短距离上升快但很快变平，说明只能感知局部相似性，两点超过一定范围ADP差异度都接近1，无法区分远近，不适合全局定位。
# G-fuse解决了远距离不可测的问题，将度量范围扩展到全局。

# %% [markdown]
# # Manifold Learning: Finding the Low-Dimensional Representation

# %% [markdown]
# ### The First Channel Chart: MDS / Isomap

# %%
nth_reduction = 10

reduced_dissimilarity_matrix_geodesic = dissimilarity_matrix_geodesic[::nth_reduction, ::nth_reduction]
embedding_isomap = MDS(metric = True, dissimilarity = "precomputed", max_iter = 300, normalized_stress = False)
proj_isomap = embedding_isomap.fit_transform(reduced_dissimilarity_matrix_geodesic)
plot_colorized(proj_isomap, groundtruth_positions[::nth_reduction], title = "Isomap Channel Chart")
#颜色基于真实位置，坐标基于Isomap，作弊?

# %% [markdown]
# ### Feature Engineering

# %% [markdown]
# 当前问题：保留 13个抽头分别计算矩阵是冗余的，且容易引入多径噪声。
# 改进方法：计算时间平均的空间协方差矩阵。即在计算相关性时，对抽头维度求和或平均。将物理意义从每个瞬间的瞬时相关转变为统计上的空间信道特征
# 这一步能极大压缩数据量，同时增强特征的鲁棒性（降噪）

# %%
class FeatureEngineeringLayer(tf.keras.layers.Layer):
    def __init__(self):
        super(FeatureEngineeringLayer, self).__init__(dtype = tf.complex64)

    def call(self, csi):
        # 输入 csi 形状: (Batch, Array, Antenna, Tap)
        # 也就是 (d, a, m, t)
        
        # 改进逻辑：
        # 1. 计算全系统的空间协方差矩阵 (Spatial Covariance Matrix)。
        # 2. 关键改变：在 't' (Tap) 维度上求和 (Summation)。
        #    指令从 "damt,dbnt->dtabmn" 改为 "damt,dbnt->dabmn"
        #    这将消除时间维度，只保留纯粹的空间角度特征。
        
        # 计算 R = H * H^H (沿时间轴 t 累加)
        spatial_covariance = tf.einsum("damt,dbnt->dabmn", csi, tf.math.conj(csi))
        
        # 归一化 (可选，除以抽头数量，使数值不随抽头数变化)
        # tap_count = tf.cast(tf.shape(csi)[-1], dtype=tf.complex64)
        # spatial_covariance = spatial_covariance / tap_count

        # 提取实部和虚部堆叠
        # 输出形状将变为: (Batch, 4, 4, 8, 8, 2)
        return tf.stack([tf.math.real(spatial_covariance), tf.math.imag(spatial_covariance)], axis = -1)

# %% [markdown]
# ### The Forward Charting Function: Defining the Neural Network

# %%
array_count = np.shape(csi_time_domain)[1]
antenna_per_array_count = np.shape(csi_time_domain)[2]
tap_count = np.shape(csi_time_domain)[3]

cc_embmodel_input = tf.keras.Input(shape=(array_count, antenna_per_array_count, tap_count), name="input", dtype = tf.complex64)
cc_embmodel_output = FeatureEngineeringLayer()(cc_embmodel_input)
cc_embmodel_output = tf.keras.layers.Flatten()(cc_embmodel_output)
cc_embmodel_output = tf.keras.layers.Dense(1024, activation = "relu")(cc_embmodel_output)
cc_embmodel_output = tf.keras.layers.BatchNormalization()(cc_embmodel_output)
cc_embmodel_output = tf.keras.layers.Dense(512, activation = "relu")(cc_embmodel_output)
cc_embmodel_output = tf.keras.layers.BatchNormalization()(cc_embmodel_output)
cc_embmodel_output = tf.keras.layers.Dense(256, activation = "relu")(cc_embmodel_output)
cc_embmodel_output = tf.keras.layers.BatchNormalization()(cc_embmodel_output)
cc_embmodel_output = tf.keras.layers.Dense(128, activation = "relu")(cc_embmodel_output)
cc_embmodel_output = tf.keras.layers.BatchNormalization()(cc_embmodel_output)
cc_embmodel_output = tf.keras.layers.Dense(64, activation = "relu")(cc_embmodel_output)
cc_embmodel_output = tf.keras.layers.BatchNormalization()(cc_embmodel_output)
cc_embmodel_output = tf.keras.layers.Dense(2, activation = "linear")(cc_embmodel_output)

cc_embmodel = tf.keras.Model(inputs=cc_embmodel_input, outputs=cc_embmodel_output, name = "ForwardChartingFunction")

# %% [markdown]
# ### Siamese Neural Network

# %%
dissimilarity_margin = np.quantile(dissimilarity_matrix_geodesic, 0.01)

def siamese_loss(y_true, y_pred):
    y_true = tf.reshape(y_true, (-1,))
    pos_A, pos_B = (y_pred[:,:2], y_pred[:,2:])
    distances_pred = tf.math.sqrt(tf.math.reduce_sum(tf.square(pos_A - pos_B), axis = 1))

    return tf.reduce_mean(tf.square(distances_pred - y_true) / (y_true + dissimilarity_margin))

# %%
input_A = tf.keras.layers.Input(shape = (array_count, antenna_per_array_count, tap_count,), dtype = tf.complex64)
input_B = tf.keras.layers.Input(shape = (array_count, antenna_per_array_count, tap_count,), dtype = tf.complex64)

embedding_A = cc_embmodel(input_A)
embedding_B = cc_embmodel(input_B)

output = tf.keras.layers.concatenate([embedding_A, embedding_B], axis=1)
model = tf.keras.models.Model([input_A, input_B], output, name = "SiameseNeuralNetwork")

# %% [markdown]
# ### Sample Selection

# %%
csi_time_domain_tensor = tf.constant(csi_time_domain)
dissimilarity_matrix_geodesic_tensor = tf.constant(dissimilarity_matrix_geodesic)

datapoint_count = tf.shape(csi_time_domain_tensor)[0].numpy()

random_integer_pairs_dataset = tf.data.Dataset.zip(tf.data.Dataset.random(), tf.data.Dataset.random())

@tf.function
def fill_pairs(randA, randB):
    return (csi_time_domain_tensor[randA % datapoint_count], csi_time_domain_tensor[randB % datapoint_count]), dissimilarity_matrix_geodesic_tensor[randA % datapoint_count, randB % datapoint_count]

random_pair_dataset = random_integer_pairs_dataset.map(fill_pairs)
# Out:
# 2026-01-09 12:50:28.602322: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:501] Allocator (GPU_0_bfc) ran out of memory trying to allocate 6.57GiB (rounded to 7053648384)requested by op _EagerConst
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2026-01-09 12:50:28.602366: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1049] BFCAllocator dump for GPU_0_bfc
# 2026-01-09 12:50:28.602395: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (256): 	Total Chunks: 26, Chunks in use: 26. 6.5KiB allocated for chunks. 6.5KiB in use in bin. 1.4KiB client-requested in use in bin.
# 2026-01-09 12:50:28.602408: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (512): 	Total Chunks: 6, Chunks in use: 6. 3.0KiB allocated for chunks. 3.0KiB in use in bin. 3.0KiB client-requested in use in bin.
# 2026-01-09 12:50:28.602420: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (1024): 	Total Chunks: 7, Chunks in use: 6. 8.0KiB allocated for chunks. 6.2KiB in use in bin. 6.0KiB client-requested in use in bin.
# 2026-01-09 12:50:28.602432: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (2048): 	Total Chunks: 5, Chunks in use: 5. 10.0KiB allocated for chunks. 10.0KiB in use in bin. 10.0KiB client-requested in use in bin.
# 2026-01-09 12:50:28.602444: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (4096): 	Total Chunks: 5, Chunks in use: 5. 20.0KiB allocated for chunks. 20.0KiB in use in bin. 20.0KiB client-requested in use in bin.
# 2026-01-09 12:50:28.602456: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (8192): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2026-01-09 12:50:28.602465: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (16384): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2026-01-09 12:50:28.602478: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (32768): 	Total Chunks: 2, Chunks in use: 1. 92.8KiB allocated for chunks. 32.0KiB in use in bin. 32.0KiB client-requested in use in bin.
# 2026-01-09 12:50:28.602488: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (65536): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2026-01-09 12:50:28.602501: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (131072): 	Total Chunks: 2, Chunks in use: 1. 285.0KiB allocated for chunks. 128.0KiB in use in bin. 128.0KiB client-requested in use in bin.
# 2026-01-09 12:50:28.602510: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (262144): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2026-01-09 12:50:28.602522: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (524288): 	Total Chunks: 2, Chunks in use: 1. 1.12MiB allocated for chunks. 512.0KiB in use in bin. 512.0KiB client-requested in use in bin.
# 2026-01-09 12:50:28.602532: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (1048576): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2026-01-09 12:50:28.602543: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (2097152): 	Total Chunks: 2, Chunks in use: 1. 4.49MiB allocated for chunks. 2.00MiB in use in bin. 2.00MiB client-requested in use in bin.
# 2026-01-09 12:50:28.602552: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (4194304): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2026-01-09 12:50:28.602564: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (8388608): 	Total Chunks: 2, Chunks in use: 1. 17.98MiB allocated for chunks. 8.00MiB in use in bin. 8.00MiB client-requested in use in bin.
# 2026-01-09 12:50:28.602574: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (16777216): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2026-01-09 12:50:28.602583: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2026-01-09 12:50:28.602597: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2026-01-09 12:50:28.602610: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (134217728): 	Total Chunks: 1, Chunks in use: 1. 133.28MiB allocated for chunks. 133.28MiB in use in bin. 133.28MiB client-requested in use in bin.
# 2026-01-09 12:50:28.602620: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (268435456): 	Total Chunks: 1, Chunks in use: 0. 701.28MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2026-01-09 12:50:28.602631: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1072] Bin for 6.57GiB was 256.00MiB, Chunk State:
# 2026-01-09 12:50:28.602650: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1078]   Size: 701.28MiB | Requested Size: 512B | in_use: 0 | bin_num: 20, prev:   Size: 133.28MiB | Requested Size: 133.28MiB | in_use: 1 | bin_num: -1
# 2026-01-09 12:50:28.602657: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1085] Next region of size 900268032
# 2026-01-09 12:50:28.602668: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd982000000 of size 1280 next 1
# 2026-01-09 12:50:28.602675: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd982000500 of size 256 next 2
# 2026-01-09 12:50:28.602682: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd982000600 of size 256 next 3
# 2026-01-09 12:50:28.602688: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd982000700 of size 256 next 4
# 2026-01-09 12:50:28.602693: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd982000800 of size 256 next 5
# 2026-01-09 12:50:28.602699: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd982000900 of size 256 next 6
# 2026-01-09 12:50:28.602705: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd982000a00 of size 256 next 7
# 2026-01-09 12:50:28.602711: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd982000b00 of size 256 next 8
# 2026-01-09 12:50:28.602717: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd982000c00 of size 256 next 9
# 2026-01-09 12:50:28.602719: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd982000d00 of size 256 next 10
# 2026-01-09 12:50:28.602721: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd982000e00 of size 4096 next 12
# 2026-01-09 12:50:28.602723: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd982001e00 of size 256 next 13
# 2026-01-09 12:50:28.602725: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd982001f00 of size 4096 next 11
# 2026-01-09 12:50:28.602726: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd982002f00 of size 4096 next 14
# 2026-01-09 12:50:28.602728: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd982003f00 of size 4096 next 17
# 2026-01-09 12:50:28.602730: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd982004f00 of size 4096 next 18
# 2026-01-09 12:50:28.602732: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd982005f00 of size 256 next 19
# 2026-01-09 12:50:28.602734: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd982006000 of size 256 next 20
# 2026-01-09 12:50:28.602736: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd982006100 of size 2048 next 21
# 2026-01-09 12:50:28.602738: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd982006900 of size 2048 next 23
# 2026-01-09 12:50:28.602740: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd982007100 of size 2048 next 24
# 2026-01-09 12:50:28.602742: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd982007900 of size 2048 next 22
# 2026-01-09 12:50:28.602744: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd982008100 of size 2048 next 25
# 2026-01-09 12:50:28.602746: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd982008900 of size 256 next 28
# 2026-01-09 12:50:28.602748: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd982008a00 of size 256 next 29
# 2026-01-09 12:50:28.602750: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd982008b00 of size 1024 next 30
# 2026-01-09 12:50:28.602752: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd982008f00 of size 1024 next 32
# 2026-01-09 12:50:28.602754: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd982009300 of size 1024 next 33
# 2026-01-09 12:50:28.602755: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd982009700 of size 1024 next 31
# 2026-01-09 12:50:28.602757: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd982009b00 of size 1024 next 34
# 2026-01-09 12:50:28.602759: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd982009f00 of size 256 next 37
# 2026-01-09 12:50:28.602761: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd98200a000 of size 256 next 38
# 2026-01-09 12:50:28.602763: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd98200a100 of size 512 next 39
# 2026-01-09 12:50:28.602765: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd98200a300 of size 512 next 41
# 2026-01-09 12:50:28.602767: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd98200a500 of size 512 next 42
# 2026-01-09 12:50:28.602769: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd98200a700 of size 512 next 40
# 2026-01-09 12:50:28.602770: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd98200a900 of size 512 next 43
# 2026-01-09 12:50:28.602772: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd98200ab00 of size 256 next 46
# 2026-01-09 12:50:28.602774: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd98200ac00 of size 256 next 47
# 2026-01-09 12:50:28.602776: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd98200ad00 of size 256 next 48
# 2026-01-09 12:50:28.602778: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd98200ae00 of size 256 next 50
# 2026-01-09 12:50:28.602780: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd98200af00 of size 256 next 51
# 2026-01-09 12:50:28.602781: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd98200b000 of size 256 next 49
# 2026-01-09 12:50:28.602783: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd98200b100 of size 256 next 52
# 2026-01-09 12:50:28.602785: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd98200b200 of size 256 next 55
# 2026-01-09 12:50:28.602787: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd98200b300 of size 256 next 56
# 2026-01-09 12:50:28.602789: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd98200b400 of size 256 next 57
# 2026-01-09 12:50:28.602791: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] Free  at 7bd98200b500 of size 1792 next 62
# 2026-01-09 12:50:28.602792: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd98200bc00 of size 512 next 63
# 2026-01-09 12:50:28.602794: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] Free  at 7bd98200be00 of size 62208 next 53
# 2026-01-09 12:50:28.602796: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd98201b100 of size 32768 next 54
# 2026-01-09 12:50:28.602799: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] Free  at 7bd982023100 of size 160768 next 44
# 2026-01-09 12:50:28.602801: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd98204a500 of size 131072 next 45
# 2026-01-09 12:50:28.602803: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] Free  at 7bd98206a500 of size 649728 next 35
# 2026-01-09 12:50:28.602805: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd982108f00 of size 524288 next 36
# 2026-01-09 12:50:28.602807: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] Free  at 7bd982188f00 of size 2610688 next 26
# 2026-01-09 12:50:28.602809: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd982406500 of size 2097152 next 27
# 2026-01-09 12:50:28.602811: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] Free  at 7bd982606500 of size 10464256 next 15
# 2026-01-09 12:50:28.602813: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd983001100 of size 8388608 next 16
# 2026-01-09 12:50:28.602815: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7bd983801100 of size 139752704 next 59
# 2026-01-09 12:50:28.602817: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] Free  at 7bd98bd48600 of size 735345152 next 18446744073709551615
# 2026-01-09 12:50:28.602819: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1110]      Summary of in-use Chunks by size:
# 2026-01-09 12:50:28.602823: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 26 Chunks of size 256 totalling 6.5KiB
# 2026-01-09 12:50:28.602825: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 6 Chunks of size 512 totalling 3.0KiB
# 2026-01-09 12:50:28.602828: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 5 Chunks of size 1024 totalling 5.0KiB
# 2026-01-09 12:50:28.602830: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 1280 totalling 1.2KiB
# 2026-01-09 12:50:28.602833: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 5 Chunks of size 2048 totalling 10.0KiB
# 2026-01-09 12:50:28.602835: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 5 Chunks of size 4096 totalling 20.0KiB
# 2026-01-09 12:50:28.602837: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 32768 totalling 32.0KiB
# 2026-01-09 12:50:28.602840: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 131072 totalling 128.0KiB
# 2026-01-09 12:50:28.602843: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 524288 totalling 512.0KiB
# 2026-01-09 12:50:28.602845: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 2097152 totalling 2.00MiB
# 2026-01-09 12:50:28.602848: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 8388608 totalling 8.00MiB
# 2026-01-09 12:50:28.602850: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 139752704 totalling 133.28MiB
# 2026-01-09 12:50:28.602853: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1117] Sum Total of in-use chunks: 143.98MiB
# 2026-01-09 12:50:28.602856: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1119] Total bytes in pool: 900268032 memory_limit_: 900268032 available bytes: 0 curr_region_allocation_bytes_: 1800536064
# 2026-01-09 12:50:28.602861: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1124] Stats:
# Limit:                       900268032
# InUse:                       150973440
# MaxInUse:                    150973440
# NumAllocs:                         108
# MaxAllocSize:                139752704
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2026-01-09 12:50:28.602865: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:512] *******************_________________________________________________________________________________
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In[20], line 2
#       1 csi_time_domain_tensor = tf.constant(csi_time_domain)
# ----> 2 dissimilarity_matrix_geodesic_tensor = tf.constant(dissimilarity_matrix_geodesic)
#       4 datapoint_count = tf.shape(csi_time_domain_tensor)[0].numpy()
#       6 random_integer_pairs_dataset = tf.data.Dataset.zip(tf.data.Dataset.random(), tf.data.Dataset.random())
#
# File /workspace/anaconda/envs/py39/lib/python3.9/site-packages/tensorflow/python/ops/weak_tensor_ops.py:142, in weak_tensor_binary_op_wrapper.<locals>.wrapper(*args, **kwargs)
#     140 def wrapper(*args, **kwargs):
#     141   if not ops.is_auto_dtype_conversion_enabled():
# --> 142     return op(*args, **kwargs)
#     143   bound_arguments = signature.bind(*args, **kwargs)
#     144   bound_arguments.apply_defaults()
#
# File /workspace/anaconda/envs/py39/lib/python3.9/site-packages/tensorflow/python/framework/constant_op.py:276, in constant(value, dtype, shape, name)
#     177 @tf_export("constant", v1=[])
#     178 def constant(
#     179     value, dtype=None, shape=None, name="Const"
#     180 ) -> Union[ops.Operation, ops._EagerTensorBase]:
#     181   """Creates a constant tensor from a tensor-like object.
#     182
#     183   Note: All eager `tf.Tensor` values are immutable (in contrast to
#    (...)
#     274     ValueError: if called on a symbolic tensor.
#     275   """
# --> 276   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     277                         allow_broadcast=True)
#
# File /workspace/anaconda/envs/py39/lib/python3.9/site-packages/tensorflow/python/framework/constant_op.py:289, in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     287     with trace.Trace("tf.constant"):
#     288       return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 289   return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     291 const_tensor = ops._create_graph_constant(  # pylint: disable=protected-access
#     292     value, dtype, shape, name, verify_shape, allow_broadcast
#     293 )
#     294 return const_tensor
#
# File /workspace/anaconda/envs/py39/lib/python3.9/site-packages/tensorflow/python/framework/constant_op.py:301, in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     297 def _constant_eager_impl(
#     298     ctx, value, dtype, shape, verify_shape
#     299 ) -> ops._EagerTensorBase:
#     300   """Creates a constant on the current device."""
# --> 301   t = convert_to_eager_tensor(value, ctx, dtype)
#     302   if shape is None:
#     303     return t
#
# File /workspace/anaconda/envs/py39/lib/python3.9/site-packages/tensorflow/python/framework/constant_op.py:108, in convert_to_eager_tensor(value, ctx, dtype)
#     106     dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     107 ctx.ensure_initialized()
# --> 108 return ops.EagerTensor(value, ctx.device_name, dtype)
#
# InternalError: Failed copying input tensor from /job:localhost/replica:0/task:0/device:CPU:0 to /job:localhost/replica:0/task:0/device:GPU:0 in order to run _EagerConst: Dst tensor is not initialized.

# %% [markdown]
# ### Training

# %%
optimizer = tf.keras.optimizers.Adam()
model.compile(loss = siamese_loss, optimizer = optimizer)

samples_per_session = 150000
learning_rates = [1e-2, 1e-2, 8e-3, 4e-3, 1e-3, 5e-4, 2e-4, 1e-4]
batch_size = [500, 1000, 1500, 2000, 3000, 4000, 5000, 6000]

for l in range(len(learning_rates)):
    print("\nTraining Session ", l + 1, "\nBatch Size: ", batch_size[l], "\nLearning rate: ", learning_rates[l])

    # Fit model
    optimizer.learning_rate.assign(learning_rates[l])
    model.fit(random_pair_dataset.batch(batch_size[l]).prefetch(tf.data.AUTOTUNE), steps_per_epoch = samples_per_session // batch_size[l])

    # Plot Channel Chart
    print("Running inference to plot channel chart")
    channel_chart_positions = cc_embmodel.predict(csi_time_domain)
    plot_colorized(channel_chart_positions, groundtruth_positions, title = "Siamese-Based Channel Chart - Session " + str(l + 1))
# Out:
# Training Session  1
# Batch Size:  500
# Learning rate:  0.01
# 2025-12-26 09:26:38.098010: I external/local_xla/xla/service/service.cc:163] XLA service 0x754e04005920 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-12-26 09:26:38.098065: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): NVIDIA L40S, Compute Capability 8.9
# 2025-12-26 09:26:38.098076: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (1): NVIDIA L40S, Compute Capability 8.9
# 2025-12-26 09:26:38.098083: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (2): NVIDIA L40S, Compute Capability 8.9
# 2025-12-26 09:26:38.098090: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (3): NVIDIA L40S, Compute Capability 8.9
# 2025-12-26 09:26:38.246585: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-12-26 09:26:38.850235: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91700
# 2025-12-26 09:26:38.964369: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-12-26 09:26:38.964441: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-12-26 09:26:38.964473: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-12-26 09:26:38.964826: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-12-26 09:26:39.461083: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_9', 4 bytes spill stores, 4 bytes spill loads
#
# 2025-12-26 09:26:39.590472: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_8', 12 bytes spill stores, 12 bytes spill loads
#
# 2025-12-26 09:26:39.702236: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-12-26 09:26:39.708735: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_10', 16 bytes spill stores, 16 bytes spill loads
#
# 2025-12-26 09:26:39.751415: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-12-26 09:26:39.760113: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_9', 4 bytes spill stores, 4 bytes spill loads
#
# 2025-12-26 09:26:39.763571: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2352', 4 bytes spill stores, 4 bytes spill loads
#
# 2025-12-26 09:26:39.781360: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2352', 4 bytes spill stores, 4 bytes spill loads
#
# 2025-12-26 09:26:39.801578: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-12-26 09:26:39.809176: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_8', 12 bytes spill stores, 12 bytes spill loads
#
# 2025-12-26 09:26:39.900560: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_10', 32 bytes spill stores, 32 bytes spill loads
#
# 2025-12-26 09:26:40.004943: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2349', 124 bytes spill stores, 124 bytes spill loads
#
# 2025-12-26 09:26:40.012403: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_10', 576 bytes spill stores, 576 bytes spill loads
#
# 2025-12-26 09:26:40.083434: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2337', 124 bytes spill stores, 124 bytes spill loads
#
# 2025-12-26 09:26:40.089805: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2349', 160 bytes spill stores, 160 bytes spill loads
#
# 2025-12-26 09:26:40.114718: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2', 60 bytes spill stores, 60 bytes spill loads
#
# 2025-12-26 09:26:40.218462: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3', 60 bytes spill stores, 60 bytes spill loads
#
# 2025-12-26 09:26:40.471126: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3', 9832 bytes spill stores, 10580 bytes spill loads
#
# 2025-12-26 09:26:40.559042: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2', 11120 bytes spill stores, 10496 bytes spill loads
#  21/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 233.5389
# I0000 00:00:1766741204.667255  149392 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 13s 9ms/step - loss: 115.7114
# Running inference to plot channel chart
# 2025-12-26 09:26:47.731769: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-12-26 09:26:47.731800: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-12-26 09:26:47.731812: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-12-26 09:26:48.206028: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_104', 28 bytes spill stores, 28 bytes spill loads
#
# 2025-12-26 09:26:48.474693: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_126', 24 bytes spill stores, 24 bytes spill loads
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# Training Session  2
# Batch Size:  1000
# Learning rate:  0.01
# 2025-12-26 09:26:54.185134: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-12-26 09:26:54.185200: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-12-26 09:26:54.185666: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-12-26 09:26:54.630641: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_9', 4 bytes spill stores, 4 bytes spill loads
#
# 2025-12-26 09:26:54.827965: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-12-26 09:26:54.851000: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_10', 16 bytes spill stores, 16 bytes spill loads
#
# 2025-12-26 09:26:54.874796: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-12-26 09:26:54.896562: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-12-26 09:26:54.945565: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_9', 4 bytes spill stores, 4 bytes spill loads
#
# 2025-12-26 09:26:54.954472: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-12-26 09:26:54.978886: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_10', 32 bytes spill stores, 32 bytes spill loads
#
# 2025-12-26 09:26:54.991919: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2349', 128 bytes spill stores, 128 bytes spill loads
#
# 2025-12-26 09:26:55.033827: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2349', 144 bytes spill stores, 144 bytes spill loads
#
# 2025-12-26 09:26:55.044773: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2337', 136 bytes spill stores, 136 bytes spill loads
#
# 2025-12-26 09:26:55.070930: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2352', 176 bytes spill stores, 176 bytes spill loads
#
# 2025-12-26 09:26:55.110379: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_10', 576 bytes spill stores, 576 bytes spill loads
#
# 2025-12-26 09:26:55.147345: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3', 60 bytes spill stores, 60 bytes spill loads
#
# 2025-12-26 09:26:55.200433: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_5', 60 bytes spill stores, 60 bytes spill loads
#
# 2025-12-26 09:26:55.213985: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2349', 192 bytes spill stores, 192 bytes spill loads
#
# 2025-12-26 09:26:55.311922: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2', 60 bytes spill stores, 60 bytes spill loads
#
# 2025-12-26 09:26:55.577239: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3', 9832 bytes spill stores, 10580 bytes spill loads
#
# 2025-12-26 09:26:55.803351: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2', 11120 bytes spill stores, 10496 bytes spill loads
#
# 2025-12-26 09:26:55.890452: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2349', 10100 bytes spill stores, 10396 bytes spill loads
#
# 2025-12-26 09:26:55.954465: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2340', 10392 bytes spill stores, 10620 bytes spill loads
#
# 2025-12-26 09:26:55.989716: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2337', 10392 bytes spill stores, 10620 bytes spill loads
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - loss: 3.6939
# Running inference to plot channel chart
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Training Session  3
# Batch Size:  1500
# Learning rate:  0.008
# 2025-12-26 09:27:04.392972: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-12-26 09:27:04.393052: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-12-26 09:27:04.761128: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_9', 4 bytes spill stores, 4 bytes spill loads
#
# 2025-12-26 09:27:04.833162: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_9', 4 bytes spill stores, 4 bytes spill loads
#
# 2025-12-26 09:27:04.836739: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_8', 12 bytes spill stores, 12 bytes spill loads
#
# 2025-12-26 09:27:04.918500: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-12-26 09:27:04.939725: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-12-26 09:27:04.968911: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_10', 16 bytes spill stores, 16 bytes spill loads
#
# 2025-12-26 09:27:04.981959: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_5', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-12-26 09:27:05.010066: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-12-26 09:27:05.023092: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2337', 132 bytes spill stores, 132 bytes spill loads
#
# 2025-12-26 09:27:05.100027: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_10', 32 bytes spill stores, 32 bytes spill loads
#
# 2025-12-26 09:27:05.149564: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_10', 576 bytes spill stores, 576 bytes spill loads
#
# 2025-12-26 09:27:05.229361: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3', 60 bytes spill stores, 60 bytes spill loads
#
# 2025-12-26 09:27:05.316504: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_5', 60 bytes spill stores, 60 bytes spill loads
#
# 2025-12-26 09:27:05.356169: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2', 60 bytes spill stores, 60 bytes spill loads
#
# 2025-12-26 09:27:05.621679: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3', 9832 bytes spill stores, 10580 bytes spill loads
#
# 2025-12-26 09:27:06.304486: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2337', 3108 bytes spill stores, 3056 bytes spill loads
#
# 2025-12-26 09:27:06.325600: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2340', 3108 bytes spill stores, 3056 bytes spill loads
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - loss: 3.0024
# Running inference to plot channel chart
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Training Session  4
# Batch Size:  2000
# Learning rate:  0.004
# 2025-12-26 09:27:15.593455: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-12-26 09:27:15.593528: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-12-26 09:27:16.017404: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_8', 12 bytes spill stores, 12 bytes spill loads
#
# 2025-12-26 09:27:16.027778: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_9', 4 bytes spill stores, 4 bytes spill loads
#
# 2025-12-26 09:27:16.168013: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_9', 4 bytes spill stores, 4 bytes spill loads
#
# 2025-12-26 09:27:16.192817: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_5', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-12-26 09:27:16.194898: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_10', 16 bytes spill stores, 16 bytes spill loads
#
# 2025-12-26 09:27:16.196940: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-12-26 09:27:16.208223: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-12-26 09:27:16.237355: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-12-26 09:27:16.307896: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_10', 32 bytes spill stores, 32 bytes spill loads
#
# 2025-12-26 09:27:16.338128: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_10', 576 bytes spill stores, 576 bytes spill loads
#
# 2025-12-26 09:27:16.505095: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3', 60 bytes spill stores, 60 bytes spill loads
#
# 2025-12-26 09:27:16.596773: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_5', 60 bytes spill stores, 60 bytes spill loads
#
# 2025-12-26 09:27:16.603756: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2', 60 bytes spill stores, 60 bytes spill loads
#
# 2025-12-26 09:27:16.995125: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3', 9832 bytes spill stores, 10580 bytes spill loads
#
# 2025-12-26 09:27:17.526881: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2337', 4052 bytes spill stores, 3800 bytes spill loads
#
# 2025-12-26 09:27:17.725789: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2340', 4052 bytes spill stores, 3800 bytes spill loads
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - loss: 2.7955
# Running inference to plot channel chart
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Training Session  5
# Batch Size:  3000
# Learning rate:  0.001
# 2025-12-26 09:27:26.582201: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-12-26 09:27:26.989922: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_7', 12 bytes spill stores, 12 bytes spill loads
#
# 2025-12-26 09:27:27.082068: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_6', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-12-26 09:27:27.106814: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_4', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-12-26 09:27:27.130194: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_473', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-12-26 09:27:27.166889: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_9', 16 bytes spill stores, 16 bytes spill loads
#
# 2025-12-26 09:27:27.185815: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-12-26 09:27:27.286059: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_9', 32 bytes spill stores, 32 bytes spill loads
#
# 2025-12-26 09:27:27.352782: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_4', 60 bytes spill stores, 60 bytes spill loads
#
# 2025-12-26 09:27:27.382686: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_9', 576 bytes spill stores, 576 bytes spill loads
#
# 2025-12-26 09:27:27.412459: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2337', 136 bytes spill stores, 136 bytes spill loads
#
# 2025-12-26 09:27:27.433860: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_473', 60 bytes spill stores, 60 bytes spill loads
#
# 2025-12-26 09:27:27.553443: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2', 60 bytes spill stores, 60 bytes spill loads
#
# 2025-12-26 09:27:28.525753: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2337', 3144 bytes spill stores, 3088 bytes spill loads
#
# 2025-12-26 09:27:28.586695: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2340', 3144 bytes spill stores, 3088 bytes spill loads
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 54ms/step - loss: 2.6531
# Running inference to plot channel chart
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Training Session  6
# Batch Size:  4000
# Learning rate:  0.0005
# 2025-12-26 09:27:38.168289: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-12-26 09:27:38.686466: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_473', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-12-26 09:27:38.928484: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_9', 576 bytes spill stores, 576 bytes spill loads
#
# 2025-12-26 09:27:39.134405: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_473', 60 bytes spill stores, 60 bytes spill loads
#
# 2025-12-26 09:27:39.983335: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2337', 4064 bytes spill stores, 3812 bytes spill loads
#
# 2025-12-26 09:27:40.077284: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2340', 4064 bytes spill stores, 3812 bytes spill loads
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 9s 69ms/step - loss: 2.6555
# Running inference to plot channel chart
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Training Session  7
# Batch Size:  5000
# Learning rate:  0.0002
# 2025-12-26 09:27:49.293235: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_4', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-12-26 09:27:49.300583: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_6', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-12-26 09:27:49.309246: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_473', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-12-26 09:27:49.312453: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_7', 12 bytes spill stores, 12 bytes spill loads
#
# 2025-12-26 09:27:49.317701: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-12-26 09:27:49.476494: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_9', 32 bytes spill stores, 32 bytes spill loads
#
# 2025-12-26 09:27:49.502789: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2337', 136 bytes spill stores, 136 bytes spill loads
#
# 2025-12-26 09:27:49.577375: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_4', 60 bytes spill stores, 60 bytes spill loads
#
# 2025-12-26 09:27:49.591802: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2', 60 bytes spill stores, 60 bytes spill loads
#
# 2025-12-26 09:27:49.742429: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_473', 60 bytes spill stores, 60 bytes spill loads
#
# 2025-12-26 09:27:50.730411: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2340', 3144 bytes spill stores, 3088 bytes spill loads
#
# 2025-12-26 09:27:50.855422: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2337', 3144 bytes spill stores, 3088 bytes spill loads
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 9s 69ms/step - loss: 2.5097
# Running inference to plot channel chart
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Training Session  8
# Batch Size:  6000
# Learning rate:  0.0001
# 2025-12-26 09:27:59.923209: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_5', 12 bytes spill stores, 12 bytes spill loads
#
# 2025-12-26 09:28:00.049886: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_473', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-12-26 09:28:00.061721: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_4', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-12-26 09:28:00.075650: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-12-26 09:28:00.272274: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_7', 32 bytes spill stores, 32 bytes spill loads
#
# 2025-12-26 09:28:00.380984: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2', 60 bytes spill stores, 60 bytes spill loads
#
# 2025-12-26 09:28:00.384313: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_473', 60 bytes spill stores, 60 bytes spill loads
#
# 2025-12-26 09:28:01.503604: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2337', 4064 bytes spill stores, 3812 bytes spill loads
#
# 2025-12-26 09:28:01.634444: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2340', 4064 bytes spill stores, 3812 bytes spill loads
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 72ms/step - loss: 2.4657
# Running inference to plot channel chart
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %% [markdown]
# # Evaluation: Optimal Affine Transform and Mean Absolute Error

# %%
channel_chart_positions = cc_embmodel.predict(csi_time_domain)

def affine_transform_channel_chart(groundtruth_pos, channel_chart_pos):
    pad = lambda x: np.hstack([x, np.ones((x.shape[0], 1))])
    unpad = lambda x: x[:,:-1]
    A, res, rank, s = np.linalg.lstsq(pad(channel_chart_pos), pad(groundtruth_pos), rcond = None)
    transform = lambda x: unpad(np.dot(pad(x), A))
    return transform(channel_chart_pos)

channel_chart_positions_transformed = affine_transform_channel_chart(groundtruth_positions, channel_chart_positions)
plot_colorized(groundtruth_positions, groundtruth_positions, title = "Ground Truth Positions")
plot_colorized(channel_chart_positions_transformed, groundtruth_positions, title = "Channel Chart After Affine Transform")
# Out:
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
errorvectors = groundtruth_positions - channel_chart_positions_transformed
errors = np.sqrt(errorvectors[:,0]**2 + errorvectors[:,1]**2)
mae = np.mean(errors)

nth_errorvector = 15
plot_colorized(channel_chart_positions_transformed, groundtruth_positions, title = "Error Vectors, MAE = " + str(mae) + "m", show = False, alpha = 0.3)
plt.quiver(channel_chart_positions_transformed[::nth_errorvector, 0], channel_chart_positions_transformed[::nth_errorvector, 1], errorvectors[::nth_errorvector, 0], errorvectors[::nth_errorvector, 1], color = "black", angles = "xy", scale_units = "xy", scale = 1)
plt.show()

# %%
count, bins_count = np.histogram(errors, bins=200)
pdf = count / sum(count)
cdf = np.cumsum(pdf)

bins_count[0] = 0
cdf = np.append([0], cdf)

plt.figure(figsize=(5, 4))
plt.plot(bins_count, cdf)
plt.xlim((0, 2))
plt.xlabel("Absolute Localization Error [m]")
plt.ylabel("CDF")
plt.grid()
plt.show()

# %% [markdown]
# # Evaluation: Continuity, Trustworthiness, Kruskal Stress

# %%
# Continuity is identical to trustworthiness, except that original space and embedding space are swapped
def continuity(*args, **kwargs):
    args = list(args)
    args[0], args[1] = args[1], args[0]
    return trustworthiness(*args, **kwargs)

def kruskal_stress(X, X_embedded):
    dist_X = distance_matrix(X, X)
    dist_X_embedded = distance_matrix(X_embedded, X_embedded)
    beta = np.divide(np.sum(dist_X * dist_X_embedded), np.sum(dist_X_embedded * dist_X_embedded))

    return np.sqrt(np.divide(np.sum(np.square((dist_X - beta * dist_X_embedded))), np.sum(dist_X * dist_X)))

# %%
# Evaluate CT / TW / KS on a subset of the whole dataset
subset_indices = random.sample(range(len(groundtruth_positions)), len(groundtruth_positions) // 5)
groundtruth_positions_subset = groundtruth_positions[subset_indices]
channel_chart_positions_subset = channel_chart_positions[subset_indices]

ct = continuity(groundtruth_positions_subset, channel_chart_positions_subset, n_neighbors = int(0.05 * len(groundtruth_positions_subset)))
tw = trustworthiness(groundtruth_positions_subset, channel_chart_positions_subset, n_neighbors = int(0.05 * len(groundtruth_positions_subset)))
ks = kruskal_stress(groundtruth_positions_subset, channel_chart_positions_subset)

print("CT: {} \nTW: {} \nKS: {}".format(*np.around((ct, tw, ks), 4)))
# Out:
# CT: 0.9953
# TW: 0.9956
# KS: 0.0823
