# %%
import deepmimo as dm

# 搜索包含'indoor'关键词的场景
scenarios = dm.search()
indoor_scenarios = [x for x in scenarios if 'i3' in x.lower()]


# 一行输出一个场景名
for x in indoor_scenarios:
    print(x)

# 下载所有indoor场景
for scen_name in indoor_scenarios:
    dataset = dm.download(scen_name)
# Out:
# i3_60
# i3_2p4
# ...
# Downloading: 100%|██████████| 88.7M/88.7M [00:26<00:00, 3.52MB/s]
# Downloading: 100%|██████████| 88.7M/88.7M [00:26<00:00, 3.52MB/s]
# ✓ Downloaded to /home/lyx/rmc/PHD_rmc/DeepMimo/deepmimo_scenarios/i3_60_downloaded.zip
# Extracting: 100%|██████████| 91/91 [00:01<00:00, 72.46file/s]
# ✓ Unzipped and moved to /home/lyx/rmc/PHD_rmc/DeepMimo/deepmimo_scenarios
# ✓ Scenario 'i3_60' ready to use!
# ...
# Downloading: 100%|██████████| 84.0M/84.0M [00:24<00:00, 3.56MB/s]
# Downloading: 100%|██████████| 84.0M/84.0M [00:24<00:00, 3.56MB/s]
# ✓ Downloaded to /home/lyx/rmc/PHD_rmc/DeepMimo/deepmimo_scenarios/i3_2p4_downloaded.zip
# Extracting: 100%|██████████| 91/91 [00:01<00:00, 76.29file/s]
# ✓ Unzipped and moved to /home/lyx/rmc/PHD_rmc/DeepMimo/deepmimo_scenarios
# ✓ Scenario 'i3_2p4' ready to use!

# %%
# Generate channels
dataset = dm.generate('i3_2p4')
# Out:
# Loading TXRX PAIR: TXset 2 (tx_idx 0) & RXset 0 (rx_idxs 66671)
# Loading TXRX PAIR: TXset 2 (tx_idx 0) & RXset 1 (rx_idxs 52288)
# Loading TXRX PAIR: TXset 3 (tx_idx 0) & RXset 0 (rx_idxs 66671)
# Loading TXRX PAIR: TXset 3 (tx_idx 0) & RXset 1 (rx_idxs 52288)
# Loading TXRX PAIR: TXset 3 (tx_idx 0) & RXset 1 (rx_idxs 52288)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/py311/lib/python3.11/site-packages/deepmimo/generator/dataset.py:182, in Dataset.__getattr__(self, key)
#     181 try:
# --> 182     value = super().__getitem__(key)
#     183 except KeyError:
#
# File ~/anaconda3/envs/py311/lib/python3.11/site-packages/deepmimo/general_utils.py:268, in DotDict.__getitem__(self, key)
#     267 """Enable dictionary-style access."""
# --> 268 return self._data[key]
#
# KeyError: '_compute_channels'
#
# ...
